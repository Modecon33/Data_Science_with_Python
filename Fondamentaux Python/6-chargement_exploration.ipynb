# %% [markdown]
# ### 🔹 1. Chargement et Exploration des Données

# %%
import pandas as pd

# Charger le fichier CSV
df = pd.read_csv("Telco-Customer-Churn.csv")

# Afficher les 5 premières lignes
print(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Infos sur les types de données
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Statistiques descriptives
print(df.describe())
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# ### 📊 Dictionnaire des Données du Dataset "Churn"
#
# | **Colonne**           | **Type**   | **Description** |
# |----------------------|-----------|----------------|
# | `customerID`        | `object`  | Identifiant unique du client |
# | `gender`            | `object`  | Sexe du client (`Male` ou `Female`) |
# | `SeniorCitizen`     | `int`     | Indique si le client est senior (`0` = Non, `1` = Oui) |
# | `Partner`           | `object`  | Le client a-t-il un partenaire (`Yes` ou `No`) |
# | `Dependents`        | `object`  | Le client a-t-il des personnes à charge (`Yes` ou `No`) |
# | `tenure`            | `int`     | Nombre de mois depuis l'inscription du client |
# | `PhoneService`      | `object`  | Le client a-t-il un service téléphonique (`Yes` ou `No`) |
# | `MultipleLines`     | `object`  | Le client a-t-il plusieurs lignes (`Yes`, `No`, ou `No phone service`) |
# | `InternetService`   | `object`  | Type d'abonnement Internet (`DSL`, `Fiber optic`, `No`) |
# | `OnlineSecurity`    | `object`  | Sécurité en ligne activée (`Yes`, `No`, `No internet service`) |
# | `OnlineBackup`      | `object`  | Sauvegarde en ligne activée (`Yes`, `No`, `No internet service`) |
# | `DeviceProtection`  | `object`  | Protection des appareils activée (`Yes`, `No`, `No internet service`) |
# | `TechSupport`       | `object`  | Support technique activé (`Yes`, `No`, `No internet service`) |
# | `StreamingTV`       | `object`  | Service de streaming TV activé (`Yes`, `No`, `No internet service`) |
# | `StreamingMovies`   | `object`  | Service de streaming films activé (`Yes`, `No`, `No internet service`) |
# | `Contract`          | `object`  | Type de contrat (`Month-to-month`, `One year`, `Two year`) |
# | `PaperlessBilling`  | `object`  | Facturation sans papier activée (`Yes` ou `No`) |
# | `PaymentMethod`     | `object`  | Mode de paiement (`Electronic check`, `Mailed check`, `Bank transfer`, `Credit card`) |
# | `MonthlyCharges`    | `float`   | Montant facturé mensuellement |
# | `TotalCharges`      | `object`  | Montant total facturé au client *(à convertir en float)* |
# | `Churn`            | `object`  | Le client a-t-il résilié (`Yes` ou `No`) |
#
# 📌 **Remarque :**
# - La colonne `TotalCharges` est au format `object` et doit être convertie en `float` pour l'analyse numérique.
# - La variable `Churn` est la cible du modèle de classification pour la prédiction de la résiliation des clients.

# %% [markdown]
# La première étape lorsqu’on reçoit des données en tant que **Data Scientist ou Ingénieur Machine Learning** est **l’exploration et la préparation des données**. Cette phase est appelée **Exploratory Data Analysis (EDA)** et comprend plusieurs sous-étapes essentielles :

# %% [markdown]
# ### 📌 1. Chargement et Inspection des Données
#
# ✅ Vérifier la structure du dataset (colonnes, types de données, taille).
# ✅ Afficher les premières lignes pour un aperçu général.

# %%
df_copy = df.copy()

# %%
# Aperçu des premières lignes
print(df_copy.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Taille du dataset (nombre de lignes et de colonnes)
print(df.shape)
# Out:
# (7043, 21)

# %%
# Types de données
print(df_copy.dtypes)
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ### 📌 2. Nettoyage des Données
#
# ✅ Vérifier et gérer les valeurs manquantes. <br>
# ✅ Détecter et corriger les incohérences (ex : types de données mal formatés).

# %%
# Vérifier les valeurs manquantes
print(df_copy.isnull().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### 📌 Techniques d'Imputation des Valeurs Manquantes
# L’imputation consiste à remplacer les valeurs manquantes dans un dataset pour éviter les erreurs lors de l’analyse et du modèle de Machine Learning.

# %% [markdown]
# ### 🔹 1. Suppression des valeurs manquantes
# 📌 Quand l'utiliser ?
#
# - Si le pourcentage de valeurs manquantes est très faible (<5%).
# - Si la colonne n'est pas essentielle à l'analyse.
#
# 📌 **Code :**
# ```python
# df.dropna(inplace=True) # Supprime les lignes contenant des valeurs manquantes
# dropna(axis=1, inplace=True) # Supprime les colonnes contenant des valeurs manquantes
# ```
# ### 🔹 2. Imputation par des valeurs statistiques
# 📌 Quand l'utiliser ?
#
# - Lorsque la colonne contient des **valeurs numériques**.
# - Si les valeurs manquantes sont **peu nombreuses**.
#
# 📌 Méthodes courantes :
# ✅ Moyenne (Mean) : Pour des distributions normales
#
# 📌 **Code :**
# ```python
# df['colonne'].fillna(df['colonne'].mean(), inplace=True)
# ```
#
# ✅ Médiane (Median) : Si la distribution est asymétrique (présence d’outliers)
#
# 📌 **Code :**
# ```python
# df['colonne'].fillna(df['colonne'].median(), inplace=True)
# ```
#
# ✅ Mode (valeur la plus fréquente) : Pour les variables catégoriques
#
# 📌 **Code :**
# ```python
# df['colonne'].fillna(df['colonne'].mode()[0], inplace=True)
# ```
#
# ### 🔹 3. Imputation par une valeur arbitraire
# 📌 Quand l'utiliser ?
#
# - Si la colonne est catégorielle et contient des valeurs manquantes.
# - On peut ajouter une catégorie "Inconnu" ou "Autre".
#
# 📌 **Code :**
# ```python
# df['colonne'].fillna('Inconnu', inplace=True)
# ```
#
# ### 🔹 4. Imputation par la Régression ou le k-NN
# 📌 Quand l'utiliser ?
#
# - Si les valeurs manquantes dépendent fortement d’autres variables.
# - Si le dataset est assez grand pour entraîner un modèle.
#
# 📌 Méthodes :
# ✅ Régression linéaire : Prédire les valeurs manquantes à partir d'autres variables.
# ✅ k-Nearest Neighbors (k-NN) : Remplacer la valeur manquante par la moyenne des k voisins les plus proches.
#
# 📌 **Code :**
# ```python
# from sklearn.impute import KNNImputer
#
# imputer = KNNImputer(n_neighbors=5)
# df_imputed = imputer.fit_transform(df)
# ```
# ### 🔹 5. Imputation avancée avec Iterative Imputer (MICE)
# 📌 Quand l'utiliser ?
#
# - Si les données manquantes dépendent de plusieurs variables.
# - Si on veut une approche plus robuste qu’une simple moyenne ou médiane.
#
# 📌 **Code :**
# ```python
# from sklearn.experimental import enable_iterative_imputer
# from sklearn.impute import IterativeImputer
#
# imputer = IterativeImputer()
# df_imputed = imputer.fit_transform(df)

# %% [markdown]
# | Méthode                    | Quand l'utiliser ?                     | Exemple                                      |
# |----------------------------|---------------------------------------|----------------------------------------------|
# | **Suppression**            | Si peu de valeurs manquantes          | `df.dropna()`                               |
# | **Moyenne/Médiane**        | Variables numériques                  | `df['col'].fillna(df['col'].mean())`        |
# | **Mode**                   | Variables catégoriques                | `df['col'].fillna(df['col'].mode()[0])`     |
# | **Valeur arbitraire**       | Ajouter une catégorie "Inconnu"       | `df['col'].fillna("Inconnu")`               |
# | **k-NN**                   | Basé sur les k voisins                | `KNNImputer(n_neighbors=5)`                 |
# | **MICE (Iterative Imputer)** | Approche plus robuste                 | `IterativeImputer()`                        |

# %%
missing_values = df_copy.isnull().sum()  # Nombre de valeurs manquantes par colonne
missing_values
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100  # Pourcentage
missing_percentage
# Out:
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %%
print(pd.DataFrame({"Valeurs Manquantes": missing_values, "Pourcentage": missing_percentage}))
# Out:
#                   Valeurs Manquantes  Pourcentage
# customerID                         0          0.0
# gender                             0          0.0
# SeniorCitizen                      0          0.0
# Partner                            0          0.0
# Dependents                         0          0.0
# tenure                             0          0.0
# PhoneService                       0          0.0
# MultipleLines                      0          0.0
# InternetService                    0          0.0
# OnlineSecurity                     0          0.0
# OnlineBackup                       0          0.0
# DeviceProtection                   0          0.0
# TechSupport                        0          0.0
# StreamingTV                        0          0.0
# StreamingMovies                    0          0.0
# Contract                           0          0.0
# PaperlessBilling                   0          0.0
# PaymentMethod                      0          0.0
# ...

# %% [markdown]
# ### Convertis la colonne "TotalCharges" en nombre (float).

# %% [markdown]
# ### 💡 Exercice
# Convertis la colonne **"TotalCharges"** en nombre (**float**).
#
# 📌 **Pourquoi ?**
# - La colonne *TotalCharges* peut être stockée sous forme de texte (*object*).
# - Pour effectuer des calculs, il faut la convertir en **float**.
#
# 📌 **Solution :**

# %%
df_copy["TotalCharges"] = pd.to_numeric(df_copy["TotalCharges"], errors="coerce")

# %%
# Types de données
print(df_copy.dtypes)
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %% [markdown]
# ### 💡 Exercice
# Affiche la moyenne des charges mensuelles (**MonthlyCharges**) pour chaque type de contrat (**Contract**).
#
# 📌 **Pourquoi ?**
# - Cela permet d’analyser l’impact du **type de contrat** sur le **montant mensuel payé**.
# - Identifier des tendances entre contrats **mensuels**, **annuels**, etc.
#
# 📌 **Solution :**

# %%
df_copy.groupby("Contract")["MonthlyCharges"].mean()
# Out:
# Contract
# Month-to-month    66.398490
# One year          65.048608
# Two year          60.770413
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# ✅ Explication :
#
# - groupby("Contract") : Regroupe les données par type de contrat
# - ["MonthlyCharges"].mean() : Calcule la moyenne des MonthlyCharges pour chaque groupe.

# %% [markdown]
# ### 💡 Exercice
# Visualiser les tendances avec Matplotlib & Seaborn**
#
# 📌 **Pourquoi ?**
# - Identifier des **tendances** et **relations** dans les données.
# - Vérifier la **distribution** des variables et leur **corrélation**.
#
# 📌 **Exemples de visualisations :**
#
# ✅ **Histogramme des charges mensuelles :**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df_copy["MonthlyCharges"], bins=30, kde=True)
plt.title("Distribution des Charges Mensuelles")
plt.xlabel("Montant ($)")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# ### 📊 Distribution des Charges Mensuelles
#
# #### 🔹 Interprétation de l'Histogramme :
# - Cet **histogramme** représente la distribution des **charges mensuelles** des clients.
# - La courbe lissée (**KDE - Kernel Density Estimation**) permet de visualiser la tendance globale.
#
# #### 🔹 Observations :
# ✅ **Pic important autour de 20$**
# - Un grand nombre de clients paient environ **20$ par mois**.
# - Il est probable que ces clients aient un forfait de base ou bénéficient d’une réduction.
#
# ✅ **Distribution multimodale**
# - On remarque plusieurs pics, suggérant **différents segments de tarification** selon les services souscrits.
# - Après le premier pic (20$), les autres groupes semblent payer entre **40$ et 100$**.
#
# ✅ **Répartition étalée jusqu’à 120$**
# - Certains clients paient des montants élevés, probablement liés à des **options supplémentaires** ou **des offres premium**.
#
# 💡 **Conclusion :**
# - **Pourquoi y a-t-il autant de clients à 20$ ?** Cela pourrait indiquer un forfait d’entrée de gamme populaire.
# - **Les clients qui paient plus sont-ils plus susceptibles de partir (churn) ?** Une analyse croisée avec le churn pourrait être intéressante ! 🚀

# %% [markdown]
# ✅ **Boxplot des charges mensuelles par type de contrat :**

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_copy["Contract"], y=df["MonthlyCharges"])
plt.title("Charges Mensuelles par Type de Contrat")
plt.xlabel("Type de Contrat")
plt.ylabel("Montant ($)")
plt.show()

# %% [markdown]
# ### 📊 Analyse des Charges Mensuelles par Type de Contrat
#
# #### 🔹 Interprétation du Boxplot :
# - Ce **boxplot** représente la distribution des charges mensuelles ($) en fonction du **type de contrat** souscrit par les clients.
# - Chaque boîte indique la **médiane** (ligne centrale), le **1er et 3e quartile** (bord inférieur et supérieur de la boîte), ainsi que les **valeurs extrêmes** (min/max des moustaches).
#
# #### 🔹 Observations :
# ✅ **Répartition similaire entre les types de contrat**
# - Les clients ont **des charges mensuelles comparables** quel que soit le type de contrat (mois par mois, 1 an, 2 ans).
#
# ✅ **Différence dans la médiane**
# - La médiane des clients en contrat **mois par mois** semble légèrement **plus élevée** que celle des contrats **1 an et 2 ans**.
# - Cela pourrait indiquer que les clients avec un engagement plus long bénéficient de **tarifs préférentiels**.
#
# ✅ **Grande dispersion des valeurs**
# - Dans chaque catégorie, il y a une **grande variabilité** des charges mensuelles, ce qui peut être dû aux **services souscrits** en plus du contrat de base.
#
# 💡 **Conclusion :**
# - **Les clients en contrat court-terme (mois par mois) ont tendance à payer plus.**
# - **Les contrats plus longs pourraient offrir une meilleure stabilité des coûts et des réductions.**
# - Il serait intéressant d'analyser si **les clients en contrat court-terme ont un taux de churn plus élevé** ! 🚀

# %% [markdown]
# ✅ **Heatmap de corrélation entre les variables numériques :**

# %%
plt.figure(figsize=(8,4))

# Sélectionner uniquement les colonnes numériques
df_numeric = df_copy.select_dtypes(include=["number"])

# Afficher la matrice de corrélation
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matrice de Corrélation (Colonnes Numériques)")
plt.show()

# %%
# Convertir 'TotalCharges' en float (avec gestion des erreurs)
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# Sélectionner uniquement les colonnes numériques
df_numeric = df.select_dtypes(include=["number"])

# Calculer la matrice de corrélation
corr_matrix = df_numeric.corr()

# Affichage de la heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Matrice de Corrélation")
plt.show()

# %% [markdown]
# ### 🔎 Matrice de Corrélation (Colonnes Numériques)
#
# #### 🔹 Interprétation du graphique :
# - La **matrice de corrélation** affiche les relations entre les variables numériques du dataset.
# - La **valeur de corrélation** varie entre **-1 et 1** :
#   - **1** : Corrélation parfaite positive (les variables évoluent dans le même sens).
#   - **0** : Aucune corrélation.
#   - **-1** : Corrélation parfaite négative (les variables évoluent en sens opposé).
#
# #### 🔹 Observations :
# ✅ **Faible corrélation globale**
# - Aucune corrélation forte entre les variables, ce qui indique qu'elles ne sont pas fortement dépendantes les unes des autres.
#
# ✅ **Corrélations spécifiques**
# - `tenure` et `MonthlyCharges` : **corrélation modérée (0.25)** → Les clients avec une plus longue ancienneté paient légèrement plus.
# - `SeniorCitizen` et `MonthlyCharges` : **corrélation faible (0.22)** → Les clients seniors ont tendance à payer un peu plus.
# - `SeniorCitizen` et `tenure` : **quasi-nulle (0.02)** → Être senior ne semble pas influencer la durée d'abonnement.
#
# 💡 **Conclusion** :
# - **Les variables ne sont pas fortement corrélées** entre elles, ce qui peut être intéressant pour la modélisation (pas de redondance).
# - Il serait pertinent de croiser ces variables avec le **Churn** pour mieux comprendre les facteurs de résiliation. 🚀

# %% [markdown]
# 📌 **La Fonction corr() ?**
# - La fonction `df.corr()` calcule la matrice de corrélation entre les **colonnes numériques**.
# - Certaines colonnes de `df_copy` contiennent **des valeurs non numériques** (ex: `customerID`, `Contract`, `PaymentMethod`, etc.).
# - Pandas ne peut pas convertir ces valeurs en **float**, ce qui provoque l'erreur.

# %% [markdown]
# #### 🔹 Analyser les variables importantes (`Churn`, `tenure`, `MonthlyCharges`...)

# %% [markdown]
# #### 📌 1. Distribution de la variable cible (`Churn`)
# ✅ Vérifier le déséquilibre des classes (`Yes` vs `No`)

# %%
sns.countplot(x=df_copy["Churn"], palette="pastel")
plt.title("Répartition de la variable Churn")
plt.show()
# Out:
# C:\Users\ameco\AppData\Local\Temp\ipykernel_30568\758503006.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_copy["Churn"], palette="pastel")

# %% [markdown]
# ### 📊 Répartition de la variable `Churn`
#
# #### 🔹 Lecture du graphique :
# - L'axe **X** représente la variable `Churn`, qui indique si un client a résilié (`Yes`) ou non (`No`).
# - L'axe **Y** représente le **nombre de clients** dans chaque catégorie.
#
# #### 🔹 Observations principales :
# ✅ **Déséquilibre des classes** :
# - Le nombre de clients **ayant résilié (`Yes`) est nettement inférieur** à ceux qui sont restés (`No`).
# - Cela indique que la majorité des clients **restent abonnés**.
#
# ✅ **Enjeu pour la modélisation** :
# - Ce déséquilibre pourrait poser un **problème pour un modèle prédictif**, car une classe (`Yes`) est sous-représentée.
# - Il faudrait envisager des techniques comme **le sur-échantillonnage (SMOTE)** ou **la pondération des classes** pour éviter un biais du modèle.
#
# 💡 **Conclusion :**
# - L'analyse plus approfondie des caractéristiques des clients ayant résilié pourrait aider à **identifier des facteurs de risque**.
# - Il serait intéressant de voir comment d'autres variables (ancienneté, type de contrat, tarifs) influencent le `Churn`. 🚀

# %% [markdown]
# #### 📌 2. Analyse de l'ancienneté des clients (tenure)
# ✅ Observer la répartition des clients selon leur durée d'abonnement.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["tenure"], bins=30, kde=True, color="skyblue")
plt.title("Distribution de l'ancienneté des clients (tenure)")
plt.xlabel("Nombre de mois")
plt.ylabel("Nombre de clients")
plt.show()

# %% [markdown]
# ### 📊 Analyse de la distribution de l'ancienneté des clients (`tenure`)
#
# #### 🔹 Lecture du graphique :
# - L'axe **X** représente l'ancienneté des clients en **mois** (`tenure`).
# - L'axe **Y** représente le **nombre de clients** correspondant à chaque valeur de `tenure`.
# - L'histogramme montre la répartition de l'ancienneté avec une **courbe KDE** (courbe de densité).
#
# #### 🔹 Observations principales :
# ✅ **Pic important à 0 mois** : Beaucoup de clients sont **très récents**, indiquant un fort taux d'acquisition.
# ✅ **Distribution en U inversé** : Moins de clients au milieu de la distribution, et davantage en fin de `tenure` (plus de 70 mois).
# ✅ **Présence de pics aux valeurs élevées** : Certains clients sont fidèles depuis **plus de 5 ans**.
#
# #### 🔹 Explication possible :
# 📌 **Taux de churn élevé chez les nouveaux clients**
# - La forte concentration à `0 mois` peut indiquer que **beaucoup de clients résilient rapidement** après l'inscription.
# - Un manque de satisfaction initiale ou une offre non adaptée peut expliquer ce départ précoce.
#
# 📌 **Deux groupes distincts de clients**
# - Certains clients **partent rapidement**, d'autres restent **fidèles sur le long terme**.
# - Cela pourrait être lié aux types de contrats (`mensuel` vs `annuel`), aux services souscrits, ou aux tarifs appliqués.
#
# 💡 **Conclusion :**
# - Il serait pertinent d'**analyser les raisons de départ des nouveaux clients** et de proposer des stratégies de rétention.
# - Comprendre pourquoi certains clients restent **plus de 5 ans** pourrait aussi aider à améliorer la fidélisation. 🚀

# %% [markdown]
# ### 📌 3. Relation entre MonthlyCharges et Churn
# ✅ Vérifier si les clients avec un montant de facturation plus élevé ont un taux de résiliation (Churn) plus important.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Churn"], y=df["MonthlyCharges"], palette="coolwarm")
plt.title("Relation entre MonthlyCharges et Churn")
plt.show()
# Out:
# C:\Users\ameco\AppData\Local\Temp\ipykernel_30568\2420222808.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["Churn"], y=df["MonthlyCharges"], palette="coolwarm")

# %% [markdown]
# ### 📊 Explication du Boxplot : Relation entre `MonthlyCharges` et `Churn`
#
# #### 🔹 Lecture du graphique :
# - L'axe **X** représente la variable `Churn` (`No` = client resté, `Yes` = client résilié).
# - L'axe **Y** représente les `MonthlyCharges` (facturation mensuelle).
# - Chaque boîte montre la répartition des valeurs :
#   - La **ligne centrale** correspond à la **médiane** (valeur centrale des données).
#   - La **boîte** représente l'intervalle interquartile (Q1 - Q3).
#   - Les **lignes horizontales** (whiskers) indiquent les valeurs extrêmes sans outliers.
#
# #### 🔹 Analyse des tendances :
# ✅ **Les clients qui résilient (`Churn = Yes`) ont en moyenne des charges mensuelles plus élevées.**
# ✅ **Les clients qui restent (`Churn = No`) ont des montants plus variés, avec une médiane plus basse.**
# ✅ L'étendue des `MonthlyCharges` est similaire dans les deux groupes, mais la médiane est plus haute pour les clients résiliés.
#
# #### 🔹 Explication possible :
# 📌 **Facteurs possibles de résiliation :**
# - Les offres plus chères (ex : fibre optique, abonnements premium) peuvent inciter les clients à partir.
# - Les clients avec des abonnements plus élevés sont peut-être plus sensibles aux prix et changent de fournisseur.
# - Une meilleure fidélisation ou des promotions pourraient réduire le churn dans cette catégorie.
#
# 💡 **Conclusion :**
# Les entreprises doivent surveiller les clients ayant des facturations élevées et proposer des stratégies pour éviter leur départ (remises, options plus flexibles, programme de fidélité). 🚀

# %% [markdown]
# ### 🔹 2. Analyse des Variables les Plus Importantes
# Voyons quelles variables influencent le plus le départ des clients (Churn).
#
# 🟢 Churn et ancienneté (tenure)

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df_copy[df_copy["Churn"]=="Yes"]["tenure"], label="Churn", shade=True, color="red")
sns.kdeplot(df_copy[df_copy["Churn"]=="No"]["tenure"], label="Non-Churn", shade=True, color="blue")
plt.title("Distribution de tenure selon le churn")
plt.xlabel("Mois d'abonnement")
plt.ylabel("Densité")
plt.legend()
plt.show()
# Out:
# C:\Users\ameco\AppData\Local\Temp\ipykernel_30568\1423012956.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_copy[df_copy["Churn"]=="Yes"]["tenure"], label="Churn", shade=True, color="red")
# C:\Users\ameco\AppData\Local\Temp\ipykernel_30568\1423012956.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_copy[df_copy["Churn"]=="No"]["tenure"], label="Non-Churn", shade=True, color="blue")

# %% [markdown]
# # 📊 Analyse de l'Ancienneté (tenure) et du Churn
#
# ## 🔎 Interprétation du Graphique
#
# 1. **Les clients qui quittent (courbe rouge) ont une faible ancienneté**
#    - Un **pic très élevé** est visible pour une **ancienneté inférieure à 10 mois**.
#    - La majorité des clients résilient leur abonnement **dans les premiers mois**.
#
# 2. **Les clients fidèles (courbe bleue) ont une répartition plus large**
#    - La distribution est **plus étalée dans le temps**.
#    - Un **deuxième pic** apparaît autour de **60 à 70 mois**, indiquant que certains clients restent longtemps.
#
# 3. **Le churn diminue avec l’ancienneté**
#    - Après **environ 20 mois**, la courbe rouge baisse fortement.
#    - Plus un client reste longtemps, **moins il a de chances de partir**.
#
#
#
# ## 📌 Conclusions et Recommandations 💡
#
# ✅ **Les nouveaux clients (<10 mois) sont les plus vulnérables au churn**
#    - Il est crucial de mettre en place des **actions de rétention dès l’onboarding**
#    - Exemples : offres spéciales, support dédié, assistance proactive.
#
# ✅ **Les clients fidèles sont plus stables**
#    - Passé **20 mois**, le churn diminue fortement.
#    - Proposer des **avantages après la première année** pourrait encourager encore plus la rétention.
#
# 🚀 **Stratégies possibles** :
# - 📢 **Programme de fidélisation** : Réductions ou avantages progressifs avec l’ancienneté.
# - 🛠 **Amélioration de l’expérience des nouveaux clients** : Communication plus active, accompagnement personnalisé.
# - 🔍 **Analyse plus approfondie** : Étudier les **services souscrits** par les clients qui partent tôt.
#
#
# Souhaitez-vous croiser cette analyse avec une autre variable, comme les charges mensuelles ? 😊

# %% [markdown]
# 🟢 Impact du type de contrat sur le churn

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="Contract", hue="Churn", data=df, palette="coolwarm")
plt.title("Impact du type de contrat sur le churn")
plt.xlabel("Type de Contrat")
plt.ylabel("Nombre de clients")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Liste des variables numériques à analyser
variables_numeriques = ["tenure", "MonthlyCharges", "TotalCharges"]  # Remplace par tes colonnes

# Tracer la distribution de chaque variable
for col in variables_numeriques:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=30, color="skyblue")
    plt.title(f"Distribution de {col}")
    plt.xlabel(col)
    plt.ylabel("Fréquence")
    plt.show()

# %%
# Calcul de l'asymétrie (skewness)
for col in variables_numeriques:
    skewness = df[col].skew()
    print(f"Asymétrie (skewness) de {col} : {skewness:.2f}")
# Out:
# Asymétrie (skewness) de tenure : 0.24
# Asymétrie (skewness) de MonthlyCharges : -0.22
# Asymétrie (skewness) de TotalCharges : 0.96

# %%
for col in variables_numeriques:
    plt.figure(figsize=(6,4))
    sns.boxplot(y=df[col], color="orange")
    plt.title(f"Boxplot de {col}")
    plt.xlabel(col)
    plt.show()
